# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response
# Out:
# <Response [200]>

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df = pd.DataFrame()

# %%
dfs = []

# %%
for i in range(1, 429):
    response = requests.get(
        f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}'
    )
    temp_df = pd.DataFrame(response.json()['results'])[
        ['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']
    ]
    dfs.append(temp_df)

# %%
# for i in range(1,429):
#     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
#     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#     df = df.append(temp_df,ignore_index=True)

# %%
df=pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555    2018       The Wedding Planner
# 8556  301502                    Blonde
# 8557  167032           Curse of Chucky
# 8558   34480       The Descent: Part 2
# 8559  664341                    Eileen
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  San Francisco's premiere wedding planner, Mary...   2001-01-26
# 8556  From her volatile childhood as Norma Jeane, th...   2022-09-16
# 8557  After her mother's mysterious death, Nica begi...   2013-10-08
# 8558  Distraught, confused, and half-wild with fear,...   2009-10-14
# 8559  During a bitter 1964 Massachusetts winter, you...   2023-12-01
#
#       popularity  vote_average  vote_count
# 0        33.1802         8.712       28969
# 1        27.2815         8.686       21898
# 2        17.5191         8.571       13234
# 3        12.7267         8.566       16745
# 4        14.0548         8.549        9437
# ...          ...           ...         ...
# 8555      3.5283         5.927        1756
# 8556      5.2495         5.925        1445
# 8557      4.9035         5.926        1640
# 8558      4.5849         5.926        1228
# 8559      6.3602         5.920         323
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
